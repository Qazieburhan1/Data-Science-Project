# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./Testimages/testtwo.jpg')
img.shape
# Out:
# (900, 1600, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (900, 1600)

# %%
plt.imshow(gray)

# %%
gray
# Out:
# array([[101, 104, 103, ...,  88,  87,  89],
#        [103, 105, 104, ...,  89,  86,  89],
#        [104, 106, 106, ...,  90,  89,  88],
#        ...,
#        [120, 117, 115, ...,   1,  28,  86],
#        [114, 115, 114, ...,   1,  29,  87],
#        [107, 111, 113, ...,   1,  29,  88]], dtype=uint8)

# %%
plt.imshow(gray,cmap="gray")

# %%
face_cascade = cv2.CascadeClassifier('./haarcascade/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascade/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[366,  33, 727, 727]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (366, 33, 727, 727)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./Testimages/testtwo.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./Testimages/testtwo.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./Testimages/testthree.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./Testimages/testthree.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/BERNIE',
#  './dataset/BIDEN',
#  './dataset/HILLARY',
#  './dataset/OBAMA',
#  './dataset/TRUMP']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# BERNIE
# Generating cropped images in folder:  ./cropped/BERNIE
# BIDEN
# Generating cropped images in folder:  ./cropped/BIDEN
# HILLARY
# Generating cropped images in folder:  ./cropped/HILLARY
# OBAMA
# Generating cropped images in folder:  ./cropped/OBAMA
# TRUMP
# Generating cropped images in folder:  ./cropped/TRUMP

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./Testimages/testtwo.jpg')
img.shape
# Out:
# (900, 1600, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (900, 1600)

# %%
gray
# Out:
# array([[101, 104, 103, ...,  88,  87,  89],
#        [103, 105, 104, ...,  89,  86,  89],
#        [104, 106, 106, ...,  90,  89,  88],
#        ...,
#        [120, 117, 115, ...,   1,  28,  86],
#        [114, 115, 114, ...,   1,  29,  87],
#        [107, 111, 113, ...,   1,  29,  88]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./haarcascade/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascade/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[366,  33, 727, 727]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (366, 33, 727, 727)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (727, 727, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./Testimages/testtwo.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./Testimages/testtwo.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./Testimages/testthree.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./Testimages/testthree.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/BERNIE',
#  './dataset/BIDEN',
#  './dataset/HILLARY',
#  './dataset/OBAMA',
#  './dataset/TRUMP']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/BERNIE
# Generating cropped images in folder:  ./dataset/cropped/BIDEN
# Generating cropped images in folder:  ./dataset/cropped/HILLARY
# Generating cropped images in folder:  ./dataset/cropped/OBAMA
# Generating cropped images in folder:  ./dataset/cropped/TRUMP

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'BERNIE': ['./dataset/cropped/BERNIE\\BERNIE1.png',
#   './dataset/cropped/BERNIE\\BERNIE10.png',
#   './dataset/cropped/BERNIE\\BERNIE11.png',
#   './dataset/cropped/BERNIE\\BERNIE12.png',
#   './dataset/cropped/BERNIE\\BERNIE13.png',
#   './dataset/cropped/BERNIE\\BERNIE14.png',
#   './dataset/cropped/BERNIE\\BERNIE15.png',
#   './dataset/cropped/BERNIE\\BERNIE16.png',
#   './dataset/cropped/BERNIE\\BERNIE17.png',
#   './dataset/cropped/BERNIE\\BERNIE18.png',
#   './dataset/cropped/BERNIE\\BERNIE19.png',
#   './dataset/cropped/BERNIE\\BERNIE2.png',
#   './dataset/cropped/BERNIE\\BERNIE20.png',
#   './dataset/cropped/BERNIE\\BERNIE21.png',
#   './dataset/cropped/BERNIE\\BERNIE22.png',
#   './dataset/cropped/BERNIE\\BERNIE23.png',
#   './dataset/cropped/BERNIE\\BERNIE24.png',
#   './dataset/cropped/BERNIE\\BERNIE25.png',
#   './dataset/cropped/BERNIE\\BERNIE26.png',
#   './dataset/cropped/BERNIE\\BERNIE27.png',
#   './dataset/cropped/BERNIE\\BERNIE28.png',
#   './dataset/cropped/BERNIE\\BERNIE29.png',
#   './dataset/cropped/BERNIE\\BERNIE3.png',
#   './dataset/cropped/BERNIE\\BERNIE30.png',
#   './dataset/cropped/BERNIE\\BERNIE31.png',
#   './dataset/cropped/BERNIE\\BERNIE32.png',
#   './dataset/cropped/BERNIE\\BERNIE4.png',
#   './dataset/cropped/BERNIE\\BERNIE5.png',
#   './dataset/cropped/BERNIE\\BERNIE6.png',
#   './dataset/cropped/BERNIE\\BERNIE7.png',
#   './dataset/cropped/BERNIE\\BERNIE8.png',
#   './dataset/cropped/BERNIE\\BERNIE9.png'],
#  'BIDEN': ['./dataset/cropped/BIDEN\\BIDEN1.png',
#   './dataset/cropped/BIDEN\\BIDEN10.png',
#   './dataset/cropped/BIDEN\\BIDEN11.png',
#   './dataset/cropped/BIDEN\\BIDEN12.png',
#   './dataset/cropped/BIDEN\\BIDEN13.png',
#   './dataset/cropped/BIDEN\\BIDEN14.png',
#   './dataset/cropped/BIDEN\\BIDEN15.png',
#   './dataset/cropped/BIDEN\\BIDEN16.png',
#   './dataset/cropped/BIDEN\\BIDEN17.png',
#   './dataset/cropped/BIDEN\\BIDEN18.png',
#   './dataset/cropped/BIDEN\\BIDEN19.png',
#   './dataset/cropped/BIDEN\\BIDEN2.png',
#   './dataset/cropped/BIDEN\\BIDEN20.png',
#   './dataset/cropped/BIDEN\\BIDEN21.png',
#   './dataset/cropped/BIDEN\\BIDEN22.png',
#   './dataset/cropped/BIDEN\\BIDEN23.png',
#   './dataset/cropped/BIDEN\\BIDEN24.png',
#   './dataset/cropped/BIDEN\\BIDEN25.png',
#   './dataset/cropped/BIDEN\\BIDEN26.png',
#   './dataset/cropped/BIDEN\\BIDEN27.png',
#   './dataset/cropped/BIDEN\\BIDEN28.png',
#   './dataset/cropped/BIDEN\\BIDEN29.png',
#   './dataset/cropped/BIDEN\\BIDEN3.png',
#   './dataset/cropped/BIDEN\\BIDEN30.png',
#   './dataset/cropped/BIDEN\\BIDEN31.png',
#   './dataset/cropped/BIDEN\\BIDEN4.png',
#   './dataset/cropped/BIDEN\\BIDEN5.png',
#   './dataset/cropped/BIDEN\\BIDEN6.png',
#   './dataset/cropped/BIDEN\\BIDEN7.png',
#   './dataset/cropped/BIDEN\\BIDEN8.png',
#   './dataset/cropped/BIDEN\\BIDEN9.png'],
#  'HILLARY': ['./dataset/cropped/HILLARY\\HILLARY1.png',
#   './dataset/cropped/HILLARY\\HILLARY10.png',
#   './dataset/cropped/HILLARY\\HILLARY11.png',
#   './dataset/cropped/HILLARY\\HILLARY12.png',
#   './dataset/cropped/HILLARY\\HILLARY13.png',
#   './dataset/cropped/HILLARY\\HILLARY14.png',
#   './dataset/cropped/HILLARY\\HILLARY15.png',
#   './dataset/cropped/HILLARY\\HILLARY16.png',
#   './dataset/cropped/HILLARY\\HILLARY17.png',
#   './dataset/cropped/HILLARY\\HILLARY18.png',
#   './dataset/cropped/HILLARY\\HILLARY19.png',
#   './dataset/cropped/HILLARY\\HILLARY2.png',
#   './dataset/cropped/HILLARY\\HILLARY20.png',
#   './dataset/cropped/HILLARY\\HILLARY21.png',
#   './dataset/cropped/HILLARY\\HILLARY22.png',
#   './dataset/cropped/HILLARY\\HILLARY23.png',
#   './dataset/cropped/HILLARY\\HILLARY24.png',
#   './dataset/cropped/HILLARY\\HILLARY25.png',
#   './dataset/cropped/HILLARY\\HILLARY26.png',
#   './dataset/cropped/HILLARY\\HILLARY27.png',
#   './dataset/cropped/HILLARY\\HILLARY28.png',
#   './dataset/cropped/HILLARY\\HILLARY29.png',
#   './dataset/cropped/HILLARY\\HILLARY3.png',
#   './dataset/cropped/HILLARY\\HILLARY30.png',
#   './dataset/cropped/HILLARY\\HILLARY31.png',
#   './dataset/cropped/HILLARY\\HILLARY32.png',
#   './dataset/cropped/HILLARY\\HILLARY33.png',
#   './dataset/cropped/HILLARY\\HILLARY34.png',
#   './dataset/cropped/HILLARY\\HILLARY35.png',
#   './dataset/cropped/HILLARY\\HILLARY36.png',
#   './dataset/cropped/HILLARY\\HILLARY37.png',
#   './dataset/cropped/HILLARY\\HILLARY38.png',
#   './dataset/cropped/HILLARY\\HILLARY39.png',
#   './dataset/cropped/HILLARY\\HILLARY4.png',
#   './dataset/cropped/HILLARY\\HILLARY40.png',
#   './dataset/cropped/HILLARY\\HILLARY41.png',
#   './dataset/cropped/HILLARY\\HILLARY42.png',
#   './dataset/cropped/HILLARY\\HILLARY43.png',
#   './dataset/cropped/HILLARY\\HILLARY5.png',
#   './dataset/cropped/HILLARY\\HILLARY6.png',
#   './dataset/cropped/HILLARY\\HILLARY7.png',
#   './dataset/cropped/HILLARY\\HILLARY8.png',
#   './dataset/cropped/HILLARY\\HILLARY9.png'],
#  'OBAMA': ['./dataset/cropped/OBAMA\\OBAMA1.png',
#   './dataset/cropped/OBAMA\\OBAMA10.png',
#   './dataset/cropped/OBAMA\\OBAMA11.png',
#   './dataset/cropped/OBAMA\\OBAMA12.png',
#   './dataset/cropped/OBAMA\\OBAMA13.png',
#   './dataset/cropped/OBAMA\\OBAMA14.png',
#   './dataset/cropped/OBAMA\\OBAMA15.png',
#   './dataset/cropped/OBAMA\\OBAMA16.png',
#   './dataset/cropped/OBAMA\\OBAMA17.png',
#   './dataset/cropped/OBAMA\\OBAMA18.png',
#   './dataset/cropped/OBAMA\\OBAMA19.png',
#   './dataset/cropped/OBAMA\\OBAMA2.png',
#   './dataset/cropped/OBAMA\\OBAMA20.png',
#   './dataset/cropped/OBAMA\\OBAMA21.png',
#   './dataset/cropped/OBAMA\\OBAMA22.png',
#   './dataset/cropped/OBAMA\\OBAMA23.png',
#   './dataset/cropped/OBAMA\\OBAMA24.png',
#   './dataset/cropped/OBAMA\\OBAMA25.png',
#   './dataset/cropped/OBAMA\\OBAMA26.png',
#   './dataset/cropped/OBAMA\\OBAMA3.png',
#   './dataset/cropped/OBAMA\\OBAMA4.png',
#   './dataset/cropped/OBAMA\\OBAMA5.png',
#   './dataset/cropped/OBAMA\\OBAMA6.png',
#   './dataset/cropped/OBAMA\\OBAMA7.png',
#   './dataset/cropped/OBAMA\\OBAMA8.png',
#   './dataset/cropped/OBAMA\\OBAMA9.png'],
#  'TRUMP': ['./dataset/cropped/TRUMP\\TRUMP1.png',
#   './dataset/cropped/TRUMP\\TRUMP10.png',
#   './dataset/cropped/TRUMP\\TRUMP11.png',
#   './dataset/cropped/TRUMP\\TRUMP12.png',
#   './dataset/cropped/TRUMP\\TRUMP13.png',
#   './dataset/cropped/TRUMP\\TRUMP14.png',
#   './dataset/cropped/TRUMP\\TRUMP15.png',
#   './dataset/cropped/TRUMP\\TRUMP16.png',
#   './dataset/cropped/TRUMP\\TRUMP17.png',
#   './dataset/cropped/TRUMP\\TRUMP18.png',
#   './dataset/cropped/TRUMP\\TRUMP19.png',
#   './dataset/cropped/TRUMP\\TRUMP2.png',
#   './dataset/cropped/TRUMP\\TRUMP20.png',
#   './dataset/cropped/TRUMP\\TRUMP21.png',
#   './dataset/cropped/TRUMP\\TRUMP22.png',
#   './dataset/cropped/TRUMP\\TRUMP23.png',
#   './dataset/cropped/TRUMP\\TRUMP24.png',
#   './dataset/cropped/TRUMP\\TRUMP25.png',
#   './dataset/cropped/TRUMP\\TRUMP3.png',
#   './dataset/cropped/TRUMP\\TRUMP4.png',
#   './dataset/cropped/TRUMP\\TRUMP5.png',
#   './dataset/cropped/TRUMP\\TRUMP6.png',
#   './dataset/cropped/TRUMP\\TRUMP7.png',
#   './dataset/cropped/TRUMP\\TRUMP8.png',
#   './dataset/cropped/TRUMP\\TRUMP9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'BERNIE': 0, 'BIDEN': 1, 'HILLARY': 2, 'OBAMA': 3, 'TRUMP': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 26],
#        [ 14],
#        [  2],
#        ...,
#        [204],
#        [ 18],
#        [149]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (157, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 100))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.725

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.78      0.70      0.74        10
#            2       0.67      0.91      0.77        11
#            3       0.86      0.75      0.80         8
#            4       0.67      0.50      0.57         4
#
#     accuracy                           0.73        40
#    macro avg       0.73      0.69      0.70        40
# weighted avg       0.73      0.72      0.72        40

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.701449
# 1        random_forest    0.477536
# 2  logistic_regression    0.709420
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                 {'logisticregression__C': 10}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.775

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.55

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.825

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  2,  0,  0,  0],
#        [ 0,  8,  0,  1,  1],
#        [ 1,  0, 10,  0,  0],
#        [ 0,  0,  0,  8,  0],
#        [ 1,  1,  0,  0,  2]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'BERNIE': 0, 'BIDEN': 1, 'HILLARY': 2, 'OBAMA': 3, 'TRUMP': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\burhan\anaconda3\lib\site-packages (1.0.1)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
